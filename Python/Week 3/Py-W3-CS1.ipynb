# %%
import pandas as pd

# %%
df = pd.read_csv("train (1).csv")

# %%
df
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %%
df.head(7)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621  3.5609  4.5322
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355 -8.0198  6.1961
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.groupby("target").mean()
# Out:
#             var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0       10.626681 -1.695770  10.665876  6.788979  11.072412 -5.146736
# 1       11.156418 -1.017613  11.156633  6.864113  11.131337 -4.336522
#
#            var_6      var_7     var_8     var_9  ...   var_190  var_191  \
# target                                           ...
# 0       5.389620  16.549306  0.262347  7.584907  ...  3.149130  7.39080
# 1       5.581966  16.514917  0.479432  7.409064  ...  3.998064  7.86456
#
#          var_192   var_193    var_194   var_195   var_196   var_197  \
# target
# 0       1.949017  3.355403  18.017716 -0.155601  2.260297  8.919032
# 1       1.738266  3.120260  17.779568 -0.021130  2.688583  8.810815
#
#           var_198   var_199
# target
# 0       15.924058 -3.415273
# 1       15.393283 -2.532243
#
# [2 rows x 200 columns]

# %%
df.groupby("target").count()
# Out:
#         ID_code   var_0   var_1   var_2   var_3   var_4   var_5   var_6  \
# target
# 0        179902  179902  179902  179902  179902  179902  179902  179902
# 1         20098   20098   20098   20098   20098   20098   20098   20098
#
#          var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  \
# target                  ...
# 0       179902  179902  ...   179902   179902   179902   179902   179902
# 1        20098   20098  ...    20098    20098    20098    20098    20098
#
#         var_195  var_196  var_197  var_198  var_199
# target
# 0        179902   179902   179902   179902   179902
# 1         20098    20098    20098    20098    20098
#
# [2 rows x 201 columns]

# %%
df = df.drop('ID_code', axis=1)

# %%
df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
df['var_0'].mean()
# Out:
# 10.67991425200015

# %%
test = df[(df['var_0'] >= df['var_0'].min()) & (df['var_0'] <= df['var_0'].mean())]

test.sort_values(by=['var_0'])
# Out:
#         target    var_0   var_1    var_2    var_3    var_4    var_5   var_6  \
# 165885       0   0.4084 -2.3580   6.4101   6.3512  11.6226   2.3006  4.3739
# 131672       1   0.4528 -8.9672   8.5680   9.9903   9.6665  -5.9784  6.8417
# 10693        0   0.5979 -0.7717   8.4321   7.1216  11.0864 -11.1819  7.2443
# 61234        0   0.8935 -1.1103  12.9898   4.0356  10.5848 -15.5852  4.1182
# 64498        0   0.9302 -4.0585  10.4719   4.2685  10.5250  -3.7847  6.4496
# ...        ...      ...     ...      ...      ...      ...      ...     ...
# 37979        0  10.6798 -4.2074   8.9397   3.8974   9.0702   1.1311  5.5586
# 179832       0  10.6799  4.8487  10.1602  10.4766  12.5674   2.2659  4.5503
# 35948        0  10.6799 -0.3459  12.6793   6.8503  10.7112  -6.9216  6.3919
# 40929        0  10.6799 -2.7908   6.8680   6.3788  12.0287 -14.5467  6.2888
# 160423       0  10.6799  4.3507   7.7910   5.3931  14.1099  -8.5624  5.7504
#
# ...

# %%
df[(df.var_6>5) & (df.var_196<2)]
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 11           0  12.7188 -7.9750  10.3757  9.0101  12.8570 -12.0852  5.6464
# 14           0  13.8080  5.0514  17.2611  8.5120  12.8517  -9.1622  5.7327
# 16           0   5.0615  0.2689  15.1325  3.6587  13.5276  -6.5477  5.2757
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199990       1  14.1475  1.8568  11.0066  3.6779  12.1944 -16.5936  5.3217
# 199991       0   9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199994       0  12.3925 -5.8821  11.2323  3.9237  10.4509  10.7262  7.0503
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
df.iloc[20000:30000, 10]
# Out:
# 20000    6.2325
# 20001    5.4199
# 20002    8.5767
# 20003    6.0312
# 20004    6.8624
#           ...
# 29995    9.0503
# 29996    5.9313
# 29997    8.9955
# 29998    7.6509
# 29999    6.4558
# Name: var_9, Length: 10000, dtype: float64

# %%
features = list(df.columns[1:11])

# %%
data = df[features].corr().abs()

# %%
data.unstack().sort_values(ascending=False)[10::2].head(10)
# Out:
# var_6  var_0    0.006983
# var_0  var_2    0.006573
# var_6  var_9    0.005697
# var_5  var_9    0.005279
# var_8  var_0    0.004962
# var_4  var_7    0.004549
# var_1  var_8    0.004098
# var_2  var_1    0.003980
# var_3  var_0    0.003801
#        var_8    0.003553
# dtype: float64

# %%
from scipy import stats

# %%
data1 = df.apply(stats.zscore).abs()

# %%
data1
# Out:
#          target     var_0     var_1     var_2     var_3     var_4     var_5  \
# 0       0.33424  0.577102  1.273737  0.451707  0.833709  0.235571  0.536430
# 1       0.33424  0.269959  0.622138  1.190360  0.688846  0.790975  1.539900
# 2       0.33424  0.681113  0.276066  0.516988  0.536516  0.305477  0.511033
# 3       0.33424  0.125158  0.129426  0.667575  0.195355  0.927992  0.410672
# 4       0.33424  0.277303  0.035610  0.817683  0.077829  0.738607  0.955574
# ...         ...       ...       ...       ...       ...       ...       ...
# 199995  0.33424  0.265814  0.279509  0.928851  1.606375  0.454632  2.120424
# 199996  0.33424  1.896359  0.202660  2.268180  0.079297  1.705783  0.699136
# 199997  0.33424  0.178710  0.845469  0.076676  0.563266  1.070350  0.043657
# 199998  0.33424  0.317467  1.723980  1.096301  0.491128  0.886530  0.712074
# 199999  0.33424  0.064567  1.008110  0.531302  0.605032  0.295332  0.688535
#
# ...

# %%
(data1<3).all(axis=1)
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 199995     True
# 199996     True
# 199997     True
# 199998     True
# 199999     True
# Length: 200000, dtype: bool
