# %% [markdown]
# ## Python Homework 1 - Week 3
# ### Shahin Mammadov

# %%
import pandas as pd

# %% [markdown]
# 1. Import dataset as FIFA.

# %%
df = pd.read_csv('fifa19.csv')

# %% [markdown]
# 2. Show first 12 entries of dataset.

# %%
df.head(12)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# 3. Get information about dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %% [markdown]
# 4. Show the number of observations in dataset.

# %%
len(df.index)
# Out:
# 18207

# %% [markdown]
# 5. Print column names.

# %%
for col in df.columns:
    print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %% [markdown]
# 6. Show 5000th observation.

# %%
print(df.loc[5000])
# Out:
# Unnamed: 0                                                  5000
# ID                                                        227394
# Name                                                 C. González
# Age                                                           25
# Photo             https://cdn.sofifa.org/players/4/19/227394.png
#                                        ...
# GKHandling                                                   6.0
# GKKicking                                                   13.0
# GKPositioning                                               13.0
# GKReflexes                                                   7.0
# Release Clause                                             €4.1M
# Name: 5000, Length: 89, dtype: object

# %% [markdown]
# 7. Select user_id column.

# %%
df["ID"]
# Out:
# 0        158023
# 1         20801
# 2        190871
# 3        193080
# 4        192985
#           ...
# 18202    238813
# 18203    243165
# 18204    241638
# 18205    246268
# 18206    246269
# Name: ID, Length: 18207, dtype: int64

# %% [markdown]
# 8. Sort teams by Club and Name columns.

# %%
by_club = df.sort_values('Club')
by_name = df.sort_values('Name')

by_club.head()
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 10312       10312  204637  J. Derstroff   26
# 5335         5335  218534    S. Adamyan   25
# 11244       11244  244280       A. Fein   19
# 9212         9212  221024   A. Sørensen   22
# 9024         9024  165176      S. Freis   33
#
#                                                 Photo Nationality  \
# 10312  https://cdn.sofifa.org/players/4/19/204637.png     Germany
# 5335   https://cdn.sofifa.org/players/4/19/218534.png     Armenia
# 11244  https://cdn.sofifa.org/players/4/19/244280.png     Germany
# 9212   https://cdn.sofifa.org/players/4/19/221024.png     Denmark
# 9024   https://cdn.sofifa.org/players/4/19/165176.png     Germany
#
#                                       Flag  Overall  Potential  \
# 10312  https://cdn.sofifa.org/flags/21.png       65         66
# 5335    https://cdn.sofifa.org/flags/3.png       70         73
# 11244  https://cdn.sofifa.org/flags/21.png       64         79
# ...

# %%
by_name.head()
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 13632       13632  228006       A. Abang   21
# 15665       15665  243896  A. Abdellaoui   25
# 3055         3055  198076   A. Abdennour   28
# 6388         6388  138698        A. Abdi   31
# 12816       12816  245438  A. Abdu Jaber   21
#
#                                                 Photo  Nationality  \
# 13632  https://cdn.sofifa.org/players/4/19/228006.png     Cameroon
# 15665  https://cdn.sofifa.org/players/4/19/243896.png      Algeria
# 3055   https://cdn.sofifa.org/players/4/19/198076.png      Tunisia
# 6388   https://cdn.sofifa.org/players/4/19/138698.png  Switzerland
# 12816  https://cdn.sofifa.org/players/4/19/245438.png      Eritrea
#
#                                        Flag  Overall  Potential  \
# 13632  https://cdn.sofifa.org/flags/103.png       62         69
# 15665   https://cdn.sofifa.org/flags/97.png       59         64
# 3055   https://cdn.sofifa.org/flags/145.png       73         73
# ...

# %% [markdown]
# 9. Filter Players whose Overall score is more than 90.

# %%
df[df['Overall'] > 90]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# ...

# %% [markdown]
# 10. Remove 'Unnamed:0' column.

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# 11. How many distinct Positions exist in dataset?

# %%
len(df['Positioning'].unique())
# Out:
# 95

# %% [markdown]
# 12. Show null values.

# %%
df[df.isnull().any(axis=1)].head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# 13. Fill empty values in 'Release Clause' column with 'unknown'.

# %%
df['Release Clause'].replace('', 'unknown')
# Out:
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#           ...
# 18202      €143K
# 18203      €113K
# 18204      €165K
# 18205      €143K
# 18206      €165K
# Name: Release Clause, Length: 18207, dtype: object

# %% [markdown]
# 14. Find mean of Age.

# %%
df['Age'].mean()
# Out:
# 25.122205745043114

# %% [markdown]
# 15. Find maximum of Shot Power.

# %%
df['ShotPower'].max()
# Out:
# 95.0

# %% [markdown]
# 16. Show footballer has maximum Shot Power.

# %%
df.loc[df['ShotPower'].idxmax()]
# Out:
# ID                                                        20801
# Name                                          Cristiano Ronaldo
# Age                                                          33
# Photo             https://cdn.sofifa.org/players/4/19/20801.png
# Nationality                                            Portugal
#                                       ...
# GKHandling                                                 11.0
# GKKicking                                                  15.0
# GKPositioning                                              14.0
# GKReflexes                                                 11.0
# Release Clause                                          €127.1M
# Name: 1, Length: 88, dtype: object

# %% [markdown]
# 17. Describe Data.

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...
